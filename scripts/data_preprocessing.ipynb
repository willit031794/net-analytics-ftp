# %% [markdown]
# # Import relevant libraries

# %%
import os
import glob
import re
import numpy as np
import pandas as pd
import unicodedata

# %%
# disable false positive warnings
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Setup path

# %%
# set up paths
base_path = os.path.join('..', 'datasets')
raw_data_path = os.path.join(base_path, 'raw_data')
cleaned_data_path = os.path.join(base_path, 'cleaned_data')

# change directory to raw_data_path
os.chdir(raw_data_path)

# %% [markdown]
# # Load data

# %%
# get folder names
folders = [name for name in os.listdir() if os.path.isdir(name)]
print(folders)
# Out:
# ['1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
# initiate a table
denorm_table = []

# load and merge all files from 1992-2020
for folder in folders:
    
    # get all file paths a folder
    file_paths = glob.glob(os.path.join(folder, '*.csv'))
    
    for file_path in file_paths: 
        
        # read file
        file = pd.read_csv(file_path)
        
        # drop unmatched column
        if 'transfer_period' in file.columns:
            file.drop(columns = 'transfer_period', inplace = True)
        
        # concat table
        if len(denorm_table) == 0:
            denorm_table = file
        else:
            # check if columns of the two tables are the same 
            assert all(denorm_table.columns == file.columns), 'Columns do not match!'
            
            # concat table
            denorm_table = pd.concat([denorm_table, file])

# %%
# remove unnecessary columns
denorm_table.drop(columns = ['league_name', 'season'], inplace = True)

denorm_table.reset_index(drop = True, inplace = True)
denorm_table.head()
# Out:
#          club_name        player_name   age        position  \
# 0  Fortuna Sittard        René Hofman  31.0    Right Winger
# 1  Fortuna Sittard      Peter Schmitz  21.0         Forward
# 2  Fortuna Sittard  Kenneth Nysaether  22.0  Centre-Forward
# 3  Fortuna Sittard      Arno van Zwam  22.0      Goalkeeper
# 4  Fortuna Sittard     Jerry Taihuttu  22.0  Centre-Forward
#
#   club_involved_name   fee transfer_movement  fee_cleaned  year
# 0            Roda JC     ?                in          NaN  1992
# 1      Helmond Sport     ?                in          NaN  1992
# 2      Lillestrøm SK     ?                in          NaN  1992
# 3        Fortuna U19     -                in          0.0  1992
# 4      Helmond Sport  Loan               out          0.0  1992

# %%
denorm_table
# Out:
#               club_name        player_name   age            position  \
# 0       Fortuna Sittard        René Hofman  31.0        Right Winger
# 1       Fortuna Sittard      Peter Schmitz  21.0             Forward
# 2       Fortuna Sittard  Kenneth Nysaether  22.0      Centre-Forward
# 3       Fortuna Sittard      Arno van Zwam  22.0          Goalkeeper
# 4       Fortuna Sittard     Jerry Taihuttu  22.0      Centre-Forward
# ...                 ...                ...   ...                 ...
# 168636         Elche CF       Iván Marcone  30.0  Defensive Midfield
# 168637         Elche CF    Diego Rodríguez  31.0          Goalkeeper
# 168638         Elche CF     Diego González  25.0         Centre-Back
# 168639         Elche CF     Claudio Medina  27.0      Centre-Forward
# 168640         Elche CF        Ramón Folch  31.0    Central Midfield
#
#        club_involved_name            fee transfer_movement  fee_cleaned  year
# 0                 Roda JC              ?                in          NaN  1992
# 1           Helmond Sport              ?                in          NaN  1992
# 2           Lillestrøm SK              ?                in          NaN  1992
# 3             Fortuna U19              -                in          0.0  1992
# 4           Helmond Sport           Loan               out          0.0  1992
# ...                   ...            ...               ...          ...   ...
# 168636       Boca Juniors           Loan                in          0.0  2020
# 168637            Defensa           Loan                in          0.0  2020
# 168638       Without Club              -                in          0.0  2020
# 168639          Burgos CF  Free transfer               out          0.0  2020
# 168640        CD Tenerife           Loan               out          0.0  2020
#
# [168641 rows x 9 columns]

# %% [markdown]
# # Preprocessing

# %%
# fix player_name by removing accent from alphabets

def strip_accents(text):

    try:
        text = unicode(text, 'utf-8')
    except NameError: 
        pass

    text = unicodedata.normalize('NFD', text)\
           .encode('ascii', 'ignore')\
           .decode("utf-8")
    return str(text)

denorm_table['player_name'] = denorm_table['player_name'].apply(strip_accents)

# %%
# `club_involved_name` == 'Without Club', 'Retired', and 'Unknown' are observed and they should be removed
to_remove = ['Without Club', 'Retired', 'Unknown']
denorm_table = denorm_table[~denorm_table['club_involved_name'].isin(to_remove)]

# %%
denorm_table.reset_index(drop = True, inplace = True)
denorm_table
# Out:
#               club_name        player_name   age            position  \
# 0       Fortuna Sittard        Rene Hofman  31.0        Right Winger
# 1       Fortuna Sittard      Peter Schmitz  21.0             Forward
# 2       Fortuna Sittard  Kenneth Nysaether  22.0      Centre-Forward
# 3       Fortuna Sittard      Arno van Zwam  22.0          Goalkeeper
# 4       Fortuna Sittard     Jerry Taihuttu  22.0      Centre-Forward
# ...                 ...                ...   ...                 ...
# 161966         Elche CF     Guido Carrillo  29.0      Centre-Forward
# 161967         Elche CF       Ivan Marcone  30.0  Defensive Midfield
# 161968         Elche CF    Diego Rodriguez  31.0          Goalkeeper
# 161969         Elche CF     Claudio Medina  27.0      Centre-Forward
# 161970         Elche CF        Ramon Folch  31.0    Central Midfield
#
#        club_involved_name            fee transfer_movement  fee_cleaned  year
# 0                 Roda JC              ?                in          NaN  1992
# 1           Helmond Sport              ?                in          NaN  1992
# 2           Lillestrøm SK              ?                in          NaN  1992
# 3             Fortuna U19              -                in          0.0  1992
# 4           Helmond Sport           Loan               out          0.0  1992
# ...                   ...            ...               ...          ...   ...
# 161966        Southampton  Free transfer                in          0.0  2020
# 161967       Boca Juniors           Loan                in          0.0  2020
# 161968            Defensa           Loan                in          0.0  2020
# 161969          Burgos CF  Free transfer               out          0.0  2020
# 161970        CD Tenerife           Loan               out          0.0  2020
#
# [161971 rows x 9 columns]

# %%
# add column `num_transfer` which represent the number of time a player moved
denorm_table['count'] = 1
denorm_table['num_transfer'] = denorm_table.groupby(['player_name', 'year'])['count'].cumcount() + 1
denorm_table['max_transfer'] = denorm_table.groupby(['player_name', 'year'])['num_transfer'].transform(np.max)
denorm_table.drop(columns = 'count', inplace = True)
denorm_table
# Out:
#               club_name        player_name   age            position  \
# 0       Fortuna Sittard        Rene Hofman  31.0        Right Winger
# 1       Fortuna Sittard      Peter Schmitz  21.0             Forward
# 2       Fortuna Sittard  Kenneth Nysaether  22.0      Centre-Forward
# 3       Fortuna Sittard      Arno van Zwam  22.0          Goalkeeper
# 4       Fortuna Sittard     Jerry Taihuttu  22.0      Centre-Forward
# ...                 ...                ...   ...                 ...
# 161966         Elche CF     Guido Carrillo  29.0      Centre-Forward
# 161967         Elche CF       Ivan Marcone  30.0  Defensive Midfield
# 161968         Elche CF    Diego Rodriguez  31.0          Goalkeeper
# 161969         Elche CF     Claudio Medina  27.0      Centre-Forward
# 161970         Elche CF        Ramon Folch  31.0    Central Midfield
#
#        club_involved_name            fee transfer_movement  fee_cleaned  year  \
# 0                 Roda JC              ?                in          NaN  1992
# 1           Helmond Sport              ?                in          NaN  1992
# 2           Lillestrøm SK              ?                in          NaN  1992
# 3             Fortuna U19              -                in          0.0  1992
# 4           Helmond Sport           Loan               out          0.0  1992
# ...                   ...            ...               ...          ...   ...
# 161966        Southampton  Free transfer                in          0.0  2020
# 161967       Boca Juniors           Loan                in          0.0  2020
# 161968            Defensa           Loan                in          0.0  2020
# 161969          Burgos CF  Free transfer               out          0.0  2020
# 161970        CD Tenerife           Loan               out          0.0  2020
#
#         num_transfer  max_transfer
# 0                  1             2
# 1                  1             1
# 2                  1             1
# 3                  1             1
# 4                  1             1
# ...              ...           ...
# 161966             5             5
# 161967             2             2
# 161968             2             2
# 161969             2             2
# 161970             2             2
#
# [161971 rows x 11 columns]

# %%
# remove players who were transferred over 4 times a year (max_transfer > 8)
target_players = denorm_table[denorm_table['max_transfer'] <= 8]['player_name'].unique()

denorm_table = denorm_table[denorm_table['player_name'].isin(target_players)]
denorm_table.drop(columns = ['num_transfer', 'max_transfer'], inplace = True)
denorm_table.reset_index(drop = True, inplace = True)
denorm_table
# Out:
#               club_name        player_name   age            position  \
# 0       Fortuna Sittard        Rene Hofman  31.0        Right Winger
# 1       Fortuna Sittard      Peter Schmitz  21.0             Forward
# 2       Fortuna Sittard  Kenneth Nysaether  22.0      Centre-Forward
# 3       Fortuna Sittard      Arno van Zwam  22.0          Goalkeeper
# 4       Fortuna Sittard     Jerry Taihuttu  22.0      Centre-Forward
# ...                 ...                ...   ...                 ...
# 161937         Elche CF     Guido Carrillo  29.0      Centre-Forward
# 161938         Elche CF       Ivan Marcone  30.0  Defensive Midfield
# 161939         Elche CF    Diego Rodriguez  31.0          Goalkeeper
# 161940         Elche CF     Claudio Medina  27.0      Centre-Forward
# 161941         Elche CF        Ramon Folch  31.0    Central Midfield
#
#        club_involved_name            fee transfer_movement  fee_cleaned  year
# 0                 Roda JC              ?                in          NaN  1992
# 1           Helmond Sport              ?                in          NaN  1992
# 2           Lillestrøm SK              ?                in          NaN  1992
# 3             Fortuna U19              -                in          0.0  1992
# 4           Helmond Sport           Loan               out          0.0  1992
# ...                   ...            ...               ...          ...   ...
# 161937        Southampton  Free transfer                in          0.0  2020
# 161938       Boca Juniors           Loan                in          0.0  2020
# 161939            Defensa           Loan                in          0.0  2020
# 161940          Burgos CF  Free transfer               out          0.0  2020
# 161941        CD Tenerife           Loan               out          0.0  2020
#
# [161942 rows x 9 columns]

# %%
# save table to csv
denorm_table.to_csv(os.path.join('..',cleaned_data_path, 'node_edge_data.csv'), index = False)

# %% [markdown]
# For performance analysis:
# - Get a table of players who were bought at least once (for performance evaluation)

# %%
# Get a table of players that were bought at least once

pattern = r"£"

slicer = []

for i in range(len(denorm_table)):
    val = bool(re.match(pattern, str(denorm_table['fee'][i])))
    slicer.append(val)

perf_eval_table = denorm_table[slicer]
perf_eval_table.reset_index(drop = True, inplace = True)
print(f'number of observation: {len(perf_eval_table)}')
perf_eval_table.head()
# Out:
# number of observation: 27376
#            club_name      player_name   age            position  \
# 0     Ajax Amsterdam    Marc Overmars  19.0         Left Winger
# 1     Ajax Amsterdam    Jari Litmanen  21.0  Attacking Midfield
# 2     Ajax Amsterdam      Aron Winter  25.0  Defensive Midfield
# 3   Sparta Rotterdam  Winston Bogarde  21.0         Centre-Back
# 4  Willem II Tilburg    Marc Overmars  19.0         Left Winger
#
#   club_involved_name      fee transfer_movement  fee_cleaned  year
# 0          Willem II  £817Th.                in        0.817  1992
# 1               MYPA   £13Th.                in        0.013  1992
# 2              Lazio   £1.17m               out        1.170  1992
# 3          Excelsior    £5Th.                in        0.005  1992
# 4               Ajax  £817Th.               out        0.817  1992

# %%
# remove unnecessary column
perf_eval_table.drop(columns = ['fee', 'position'], inplace = True)

# %%
# clean data
perf_eval_table.dropna(inplace = True)
perf_eval_table.reset_index(drop = True, inplace = True)

# %%
# save table to csv
perf_eval_table.to_csv(os.path.join('..', cleaned_data_path, 'perf_eval_table.csv'), index = False)

# %%
perf_eval_table[perf_eval_table['player_name'] == 'Neymar']
# Out:
#                  club_name player_name   age club_involved_name  \
# 18418         FC Barcelona      Neymar  21.0          Santos FC
# 22849  Paris Saint-Germain      Neymar  25.0       FC Barcelona
# 23533         FC Barcelona      Neymar  25.0           Paris SG
#
#       transfer_movement  fee_cleaned  year
# 18418                in        79.38  2013
# 22849                in       199.80  2017
# 23533               out       199.80  2017

# %%
perf_eval_table.sort_values(by = 'fee_cleaned', ascending = False)
# Out:
#                  club_name           player_name   age club_involved_name  \
# 23533         FC Barcelona                Neymar  25.0           Paris SG
# 22849  Paris Saint-Germain                Neymar  25.0       FC Barcelona
# 22694         Liverpool FC     Philippe Coutinho  25.0       FC Barcelona
# 23652         FC Barcelona     Philippe Coutinho  25.0          Liverpool
# 24157  Paris Saint-Germain         Kylian Mbappe  19.0             Monaco
# ...                    ...                   ...   ...                ...
# 3         Sparta Rotterdam       Winston Bogarde  21.0          Excelsior
# 24761        Akhmat Grozny  Aleksandr Sheplyakov  21.0     Dnepr Smolensk
# 338         Ajax Amsterdam         Finidi George  22.0          Sharks FC
# 12493       Belenenses SAD              Carciano  27.0           Ceará SC
# 3062     Huddersfield Town       Danny Schofield  18.0         Brodsworth
#
#       transfer_movement  fee_cleaned  year
# 23533               out      199.800  2017
# 22849                in      199.800  2017
# 22694               out      130.500  2017
# 23652                in      130.500  2017
# 24157                in      130.500  2018
# ...                 ...          ...   ...
# 3                    in        0.005  1992
# 24761                in        0.005  2018
# 338                  in        0.004  1993
# 12493                in        0.004  2008
# 3062                 in        0.002  1998
#
# [27316 rows x 7 columns]
